# %% [markdown]
# ## Aufgabe 4
# ## Import von Bibliotheken

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as sm

# %matplotlib inline
import matplotlib.pyplot as plt
sns.set(context="paper", font="monospace")

# %% [markdown]
# ## Einlesen der Dateien

# %%
df_players = pd.read_csv('data/players.csv', memory_map=True)
df_match_50000 = pd.read_csv('data/match.csv' ,memory_map=True, nrows=50000)
df_match_500 = pd.read_csv('data/match.csv' ,memory_map=True, nrows=500)
df_hero_names = pd.read_csv('data/hero_names.csv', memory_map=True  )
# df_chat = pd.read_csv('data/dota-2-matches/chat.csv', memory_map=True)

# %% [markdown]
# ## Auswahl der benötigten Daten

# %%
full_list_match = list(df_match_50000.columns)
full_list_players = list(df_players.columns)
wanted = ['match_id','duration','radiant_win']
# df_match_50000.drop(full_list-wanted)
col_players = df_players[['match_id',
 'account_id',
 'hero_id',
 'player_slot',
 'gold',
 'gold_spent',
 'gold_per_min',
 'xp_per_min',
 'kills',
 'deaths',
 'assists',
 'denies',
 'last_hits',
 'stuns',
 'hero_damage',
 'hero_healing',
 'tower_damage']]

# %%
col_players.head()
# Out:
#    match_id  account_id  hero_id  player_slot  gold  gold_spent  gold_per_min  \
# 0         0           0       86            0  3261       10960           347
# 1         0           1       51            1  2954       17760           494
# 2         0           0       83            2   110       12195           350
# 3         0           2       11            3  1179       22505           599
# 4         0           3       67            4  3307       23825           613
#
#    xp_per_min  kills  deaths  assists  denies  last_hits    stuns  \
# 0         362      9       3       18       1         30  76.7356
# 1         659     13       3       18       9        109  87.4164
# 2         385      0       4       15       1         58     None
# 3         605      8       4       19       6        271     None
# 4         762     20       3       17      13        245     None
#
#    hero_damage  hero_healing  tower_damage
# 0         8690           218           143
# 1        23747             0           423
# 2         4217          1595           399
# 3        14832          2714          6055
# 4        33740           243          1833

# %% [markdown]
# ## Überprüfen auf fehlenden Werte

# %%
print ("Na Werte \t" +  str(df_match_50000.isnull().sum()))
# Out:
# Na Werte 	match_id                   0
# start_time                 0
# duration                   0
# tower_status_radiant       0
# tower_status_dire          0
# barracks_status_dire       0
# barracks_status_radiant    0
# first_blood_time           0
# game_mode                  0
# radiant_win                0
# negative_votes             0
# positive_votes             0
# cluster                    0
# dtype: int64

# %%
print ("Na Werte \t" +  str(df_players.isnull().sum()))
print("\n\nDie NA Werte sind nicht zu bereinigen, mit ihnen muss umgegangen werden.")
# Out:
# Na Werte 	match_id                                  0
# account_id                                0
# hero_id                                   0
# player_slot                               0
# gold                                      0
# gold_spent                                0
# gold_per_min                              0
# xp_per_min                                0
# kills                                     0
# deaths                                    0
# assists                                   0
# denies                                    0
# last_hits                                 0
# stuns                                     0
# hero_damage                               0
# hero_healing                              0
# tower_damage                              0
# item_0                                    0
# item_1                                    0
# item_2                                    0
# item_3                                    0
# item_4                                    0
# item_5                                    0
# level                                     0
# leaver_status                             0
# xp_hero                                1883
# xp_creep                                 68
# xp_roshan                            320438
# xp_other                              21036
# gold_other                            94897
#                                       ...
# unit_order_attack_target                105
# unit_order_cast_position               2269
# unit_order_cast_target                16674
# unit_order_cast_target_tree           35712
# unit_order_cast_no_target               892
# unit_order_cast_toggle               401211
# unit_order_hold_position             137277
# unit_order_train_ability                 73
# unit_order_drop_item                 288667
# unit_order_give_item                 394631
# unit_order_pickup_item               244658
# unit_order_pickup_rune                74517
# unit_order_purchase_item                 57
# unit_order_sell_item                 111866
# unit_order_disassemble_item          485446
# unit_order_move_item                   4264
# unit_order_cast_toggle_auto          463670
# unit_order_stop                      412425
# unit_order_taunt                     500000
# unit_order_buyback                   352233
# unit_order_glyph                     273230
# unit_order_eject_item_from_stash     468736
# unit_order_cast_rune                 499991
# unit_order_ping_ability              160852
# unit_order_move_to_direction         496449
# unit_order_patrol                    500000
# unit_order_vector_target_position    500000
# unit_order_radar                     500000
# unit_order_set_item_combine_lock     500000
# unit_order_continue                  500000
# dtype: int64
#
#
# Die NA Werte sind nicht zu bereinigen, mit ihnen muss umgegangen werden.

# %%
print ("Na Werte \t" +  str(df_hero_names.isnull().sum()))
# Out:
# Na Werte 	name              0
# hero_id           0
# localized_name    0
# dtype: int64

# %% [markdown]
# ## Überprüfung auf Ausreiser

# %%
# alle Spalten von df_players
cols = df_players.select_dtypes(include=[np.number]).columns
fig, axes = plt.subplots(nrows=len(cols), ncols=1, figsize=(5, 15))

for i in range(len(cols)):
    sns.boxplot(x=cols[i], orient='h', data=df_players, ax=axes[i])

fig.tight_layout()

plt.show()

# %%
# einzelne Spalten von df_players bzw alle spalten von col_players in boxplot anzeigen
cols = col_players.select_dtypes(include=[np.number]).columns
fig, axes = plt.subplots(nrows=len(cols), ncols=1, figsize=(5, 15))

for i in range(len(cols)):
    sns.boxplot(x=cols[i], orient='h', data=col_players, ax=axes[i])

fig.tight_layout()

plt.show()

# %%
# Ausreiser mit Hilfe von Boxplots in df_match_50000 visualisieren
cols = df_match_50000.select_dtypes(include=[np.number]).columns
fig, axes = plt.subplots(nrows=len(cols), ncols=1, figsize=(5, 15))

for i in range(len(cols)):
    sns.boxplot(x=cols[i], orient='h', data=df_match_50000, ax=axes[i])

fig.tight_layout()

plt.show()

# %% [markdown]
# ## Gibt es Helden die erfolgreicher sind als andere?

# %%
# Datentypen der Spalten von df_match_50000
# hier kann man erkennen, dass die Spalte radiant_win einen boolischen Wert hat
df_match_50000.dtypes
# Out:
# match_id                   int64
# start_time                 int64
# duration                   int64
# tower_status_radiant       int64
# tower_status_dire          int64
# barracks_status_dire       int64
# barracks_status_radiant    int64
# first_blood_time           int64
# game_mode                  int64
# radiant_win                 bool
# negative_votes             int64
# positive_votes             int64
# cluster                    int64
# dtype: object

# %%
# Anzahl Zeilen und Spalten von df_match_50000
df_match_50000.shape
# Out:
# (50000, 13)

# %%
# Anzahl Zeilen und Spalten von df_players
df_players.shape
# Out:
# (500000, 73)

# %%
# Aus boolischen Werten Spalte "radiant_win" in int umwandeln
df_match_50000["radiant_win"] = df_match_50000.radiant_win.astype(int)

# %%
df_match_50000["radiant_win"].head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: radiant_win, dtype: int32

# %%
# beide Datensätze verbinduen mit Hilfe von match_id und Betrahtung nur von Teammitglieder mit player_slot 0-4
mat = df_match_50000.merge(df_match_50000,on='match_id').merge(df_players[df_players["player_slot"]<6],on='match_id')
mat.head()
# Out:
#    match_id  start_time_x  duration_x  tower_status_radiant_x  \
# 0         0    1446750112        2375                    1982
# 1         0    1446750112        2375                    1982
# 2         0    1446750112        2375                    1982
# 3         0    1446750112        2375                    1982
# 4         0    1446750112        2375                    1982
#
#    tower_status_dire_x  barracks_status_dire_x  barracks_status_radiant_x  \
# 0                    4                       3                         63
# 1                    4                       3                         63
# 2                    4                       3                         63
# 3                    4                       3                         63
# 4                    4                       3                         63
#
#    first_blood_time_x  game_mode_x  radiant_win_x         ...           \
# 0                   1           22              1         ...
# 1                   1           22              1         ...
# 2                   1           22              1         ...
# 3                   1           22              1         ...
# 4                   1           22              1         ...
#
#    unit_order_glyph  unit_order_eject_item_from_stash  unit_order_cast_rune  \
# 0               NaN                               NaN                   NaN
# 1               NaN                               NaN                   NaN
# 2               NaN                               NaN                   NaN
# 3               1.0                               NaN                   NaN
# 4               3.0                               NaN                   NaN
#
#    unit_order_ping_ability  unit_order_move_to_direction  unit_order_patrol  \
# 0                      6.0                           NaN                NaN
# 1                     14.0                           NaN                NaN
# 2                     17.0                           NaN                NaN
# 3                     13.0                           NaN                NaN
# 4                     23.0                           NaN                NaN
#
#    unit_order_vector_target_position  unit_order_radar  \
# 0                                NaN               NaN
# 1                                NaN               NaN
# 2                                NaN               NaN
# 3                                NaN               NaN
# 4                                NaN               NaN
#
#    unit_order_set_item_combine_lock  unit_order_continue
# 0                               NaN                  NaN
# 1                               NaN                  NaN
# 2                               NaN                  NaN
# 3                               NaN                  NaN
# 4                               NaN                  NaN
#
# [5 rows x 97 columns]

# %%
# warum mat mehr Spalten hat als beide verbundene Datensätze
mat.shape
# Out:
# (250000, 97)

# %%
# mat.groupby('hero_id').mean()['radiant_win_x']
df_gb_heroID = pd.DataFrame(mat.groupby('hero_id').mean()['radiant_win_x'], index=np.arange(113))
df_gb_heroID.columns =["winrate"]
df_gb_heroID["hero_id"] = np.arange(1,114)
df_gb_heroID
# Out:
#       winrate  hero_id
# 0    0.136364        1
# 1    0.484149        2
# 2    0.454823        3
# 3    0.487500        4
# 4    0.469646        5
# 5    0.562169        6
# 6    0.518660        7
# 7    0.521411        8
# 8    0.524041        9
# 9    0.539709       10
# 10   0.446667       11
# 11   0.531194       12
# 12   0.471668       13
# 13   0.435838       14
# 14   0.514019       15
# 15   0.506250       16
# 16   0.489172       17
# 17   0.428571       18
# 18   0.535632       19
# 19   0.503440       20
# 20   0.542603       21
# 21   0.500581       22
# 22   0.581858       23
# 23   0.487023       24
# 24        NaN       25
# 25   0.451009       26
# 26   0.492295       27
# 27   0.561659       28
# 28   0.576860       29
# 29   0.498328       30
# ..        ...      ...
# 83   0.532131       84
# 84   0.541724       85
# 85   0.592802       86
# 86   0.472772       87
# 87   0.539260       88
# 88   0.502203       89
# 89   0.463265       90
# 90   0.470968       91
# 91   0.474390       92
# 92   0.520343       93
# 93   0.497965       94
# 94   0.540928       95
# 95   0.500000       96
# 96   0.537797       97
# 97   0.470041       98
# 98   0.472889       99
# 99   0.485469      100
# 100  0.535433      101
# 101  0.453104      102
# 102  0.599644      103
# 103  0.507282      104
# 104  0.506303      105
# 105  0.467337      106
# 106  0.505670      107
# 107  0.528234      108
# 108       NaN      109
# 109  0.536388      110
# 110  0.536697      111
# 111  0.498008      112
# 112  0.530549      113
#
# [113 rows x 2 columns]

# %%
#df_hero_names.head(113)
df_hero_names = df_hero_names.merge(df_gb_heroID, left_on='hero_id', right_on='hero_id', how='outer')
df_hero_names.head(113)
# Out:
#                                   name  hero_id       localized_name   winrate
# 0               npc_dota_hero_antimage        1            Anti-Mage  0.136364
# 1                    npc_dota_hero_axe        2                  Axe  0.484149
# 2                   npc_dota_hero_bane        3                 Bane  0.454823
# 3            npc_dota_hero_bloodseeker        4          Bloodseeker  0.487500
# 4         npc_dota_hero_crystal_maiden        5       Crystal Maiden  0.469646
# 5            npc_dota_hero_drow_ranger        6          Drow Ranger  0.562169
# 6            npc_dota_hero_earthshaker        7          Earthshaker  0.518660
# 7             npc_dota_hero_juggernaut        8           Juggernaut  0.521411
# 8                 npc_dota_hero_mirana        9               Mirana  0.524041
# 9              npc_dota_hero_morphling       10            Morphling  0.539709
# 10             npc_dota_hero_nevermore       11         Shadow Fiend  0.446667
# 11        npc_dota_hero_phantom_lancer       12       Phantom Lancer  0.531194
# 12                  npc_dota_hero_puck       13                 Puck  0.471668
# 13                 npc_dota_hero_pudge       14                Pudge  0.435838
# 14                 npc_dota_hero_razor       15                Razor  0.514019
# 15             npc_dota_hero_sand_king       16            Sand King  0.506250
# 16          npc_dota_hero_storm_spirit       17         Storm Spirit  0.489172
# 17                  npc_dota_hero_sven       18                 Sven  0.428571
# 18                  npc_dota_hero_tiny       19                 Tiny  0.535632
# 19        npc_dota_hero_vengefulspirit       20      Vengeful Spirit  0.503440
# 20            npc_dota_hero_windrunner       21           Windranger  0.542603
# 21                  npc_dota_hero_zuus       22                 Zeus  0.500581
# 22                npc_dota_hero_kunkka       23               Kunkka  0.581858
# 23                  npc_dota_hero_lina       25                 Lina       NaN
# 24                  npc_dota_hero_lion       26                 Lion  0.451009
# 25         npc_dota_hero_shadow_shaman       27        Shadow Shaman  0.492295
# 26               npc_dota_hero_slardar       28              Slardar  0.561659
# 27            npc_dota_hero_tidehunter       29           Tidehunter  0.576860
# 28          npc_dota_hero_witch_doctor       30         Witch Doctor  0.498328
# 29                  npc_dota_hero_lich       31                 Lich  0.532731
# ..                                 ...      ...                  ...       ...
# 83               npc_dota_hero_undying       85              Undying  0.541724
# 84                npc_dota_hero_rubick       86               Rubick  0.592802
# 85             npc_dota_hero_disruptor       87            Disruptor  0.472772
# 86          npc_dota_hero_nyx_assassin       88         Nyx Assassin  0.539260
# 87            npc_dota_hero_naga_siren       89           Naga Siren  0.502203
# 88   npc_dota_hero_keeper_of_the_light       90  Keeper of the Light  0.463265
# 89                  npc_dota_hero_wisp       91                   Io  0.470968
# 90                npc_dota_hero_visage       92               Visage  0.474390
# 91                 npc_dota_hero_slark       93                Slark  0.520343
# 92                npc_dota_hero_medusa       94               Medusa  0.497965
# 93         npc_dota_hero_troll_warlord       95        Troll Warlord  0.540928
# 94               npc_dota_hero_centaur       96    Centaur Warrunner  0.500000
# 95             npc_dota_hero_magnataur       97               Magnus  0.537797
# 96              npc_dota_hero_shredder       98            Timbersaw  0.470041
# 97           npc_dota_hero_bristleback       99          Bristleback  0.472889
# 98                  npc_dota_hero_tusk      100                 Tusk  0.485469
# 99         npc_dota_hero_skywrath_mage      101        Skywrath Mage  0.535433
# 100              npc_dota_hero_abaddon      102              Abaddon  0.453104
# 101          npc_dota_hero_elder_titan      103          Elder Titan  0.599644
# 102     npc_dota_hero_legion_commander      104     Legion Commander  0.507282
# 103              npc_dota_hero_techies      105              Techies  0.506303
# 104         npc_dota_hero_ember_spirit      106         Ember Spirit  0.467337
# 105         npc_dota_hero_earth_spirit      107         Earth Spirit  0.505670
# 106    npc_dota_hero_abyssal_underlord      108            Underlord  0.528234
# 107          npc_dota_hero_terrorblade      109          Terrorblade       NaN
# 108              npc_dota_hero_phoenix      110              Phoenix  0.536388
# 109               npc_dota_hero_oracle      111               Oracle  0.536697
# 110        npc_dota_hero_winter_wyvern      112        Winter Wyvern  0.498008
# 111           npc_dota_hero_arc_warden      113           Arc Warden  0.530549
# 112                                NaN       24                  NaN  0.487023
#
# [113 rows x 4 columns]

# %%
df_hero_names.sort_values("winrate")
# Out:
#                                   name  hero_id       localized_name   winrate
# 0               npc_dota_hero_antimage        1            Anti-Mage  0.136364
# 52          npc_dota_hero_life_stealer       54          Lifestealer  0.411295
# 78            npc_dota_hero_lone_druid       80           Lone Druid  0.411848
# 60         npc_dota_hero_bounty_hunter       62        Bounty Hunter  0.414465
# 79          npc_dota_hero_chaos_knight       81         Chaos Knight  0.416162
# 57                npc_dota_hero_huskar       59               Huskar  0.426716
# 17                  npc_dota_hero_sven       18                 Sven  0.428571
# 13                 npc_dota_hero_pudge       14                Pudge  0.435838
# 10             npc_dota_hero_nevermore       11         Shadow Fiend  0.446667
# 24                  npc_dota_hero_lion       26                 Lion  0.451009
# 100              npc_dota_hero_abaddon      102              Abaddon  0.453104
# 2                   npc_dota_hero_bane        3                 Bane  0.454823
# 33                npc_dota_hero_sniper       35               Sniper  0.456884
# 34             npc_dota_hero_necrolyte       36            Necrophos  0.457364
# 64                  npc_dota_hero_chen       66                 Chen  0.459839
# 88   npc_dota_hero_keeper_of_the_light       90  Keeper of the Light  0.463265
# 40         npc_dota_hero_skeleton_king       42          Wraith King  0.463631
# 104         npc_dota_hero_ember_spirit      106         Ember Spirit  0.467337
# 51                npc_dota_hero_furion       53     Nature's Prophet  0.469256
# 4         npc_dota_hero_crystal_maiden        5       Crystal Maiden  0.469646
# 96              npc_dota_hero_shredder       98            Timbersaw  0.470041
# 89                  npc_dota_hero_wisp       91                   Io  0.470968
# 12                  npc_dota_hero_puck       13                 Puck  0.471668
# 81                npc_dota_hero_treant       83     Treant Protector  0.471963
# 38            npc_dota_hero_venomancer       40           Venomancer  0.472062
# 85             npc_dota_hero_disruptor       87            Disruptor  0.472772
# 97           npc_dota_hero_bristleback       99          Bristleback  0.472889
# 90                npc_dota_hero_visage       92               Visage  0.474390
# 75                 npc_dota_hero_lycan       77                Lycan  0.480620
# 53             npc_dota_hero_dark_seer       55            Dark Seer  0.481215
# ..                                 ...      ...                  ...       ...
# 108              npc_dota_hero_phoenix      110              Phoenix  0.536388
# 109               npc_dota_hero_oracle      111               Oracle  0.536697
# 95             npc_dota_hero_magnataur       97               Magnus  0.537797
# 86          npc_dota_hero_nyx_assassin       88         Nyx Assassin  0.539260
# 9              npc_dota_hero_morphling       10            Morphling  0.539709
# 39         npc_dota_hero_faceless_void       41        Faceless Void  0.540810
# 93         npc_dota_hero_troll_warlord       95        Troll Warlord  0.540928
# 83               npc_dota_hero_undying       85              Undying  0.541724
# 20            npc_dota_hero_windrunner       21           Windranger  0.542603
# 49            npc_dota_hero_rattletrap       51            Clockwerk  0.545367
# 68                  npc_dota_hero_ursa       70                 Ursa  0.550327
# 74    npc_dota_hero_obsidian_destroyer       76    Outworld Devourer  0.551839
# 70            npc_dota_hero_gyrocopter       72           Gyrocopter  0.556010
# 47         npc_dota_hero_dragon_knight       49        Dragon Knight  0.556239
# 26               npc_dota_hero_slardar       28              Slardar  0.561659
# 5            npc_dota_hero_drow_ranger        6          Drow Ranger  0.562169
# 36           npc_dota_hero_beastmaster       38          Beastmaster  0.566120
# 30                  npc_dota_hero_riki       32                 Riki  0.574682
# 69        npc_dota_hero_spirit_breaker       71       Spirit Breaker  0.575553
# 27            npc_dota_hero_tidehunter       29           Tidehunter  0.576860
# 31                npc_dota_hero_enigma       33               Enigma  0.580709
# 22                npc_dota_hero_kunkka       23               Kunkka  0.581858
# 35               npc_dota_hero_warlock       37              Warlock  0.590292
# 84                npc_dota_hero_rubick       86               Rubick  0.592802
# 41         npc_dota_hero_death_prophet       43        Death Prophet  0.597286
# 101          npc_dota_hero_elder_titan      103          Elder Titan  0.599644
# 66    npc_dota_hero_ancient_apparition       68   Ancient Apparition  0.606761
# 56           npc_dota_hero_enchantress       58          Enchantress  0.608492
# 23                  npc_dota_hero_lina       25                 Lina       NaN
# 107          npc_dota_hero_terrorblade      109          Terrorblade       NaN
#
# [113 rows x 4 columns]

# %%
sns.violinplot(data=df_hero_names.winrate, orient="h");

# sns.barplot(orient="h",data=df_hero_names.sort("winrate"),x="localized_name", y="winrate")

# %% [markdown]
# ## Prüfen ob gewisse Helden öfter gespielt werden als andere

# %%
df_hero_names = mat.hero_id.value_counts().to_frame(name="total_plays").merge(df_hero_names,left_index=True, right_index=True)

# %%
sns.regplot(data=df_hero_names, y="winrate", x="total_plays")

# %%
# Entfernen des Ausreisers
df_hero_names.drop(df_hero_names.winrate<0.14, inplace=True)

# %%
 sns.regplot(data=df_hero_names, y="winrate", x="total_plays")

# %%
df_hero_names.corr()
# Out:
#              total_plays   hero_id   winrate
# total_plays     1.000000 -0.246683  0.157869
# hero_id        -0.246683  1.000000 -0.013915
# winrate         0.157869 -0.013915  1.000000

# %% [markdown]
# ## Ist die Winrate der Champions abhängig von der Spieldauer?

# %%
mat.shape
# Out:
# (250000, 97)

# %%
# df_mph nach 'duration_x' aufsteigend sortiert
df_mat_sort = mat.sort_values(by='duration_x')
df_mat_sort.head()
# Out:
#         match_id  start_time_x  duration_x  tower_status_radiant_x  \
# 157194     31438    1447625450          59                    2047
# 157190     31438    1447625450          59                    2047
# 157191     31438    1447625450          59                    2047
# 157192     31438    1447625450          59                    2047
# 157193     31438    1447625450          59                    2047
#
#         tower_status_dire_x  barracks_status_dire_x  \
# 157194                 2047                      63
# 157190                 2047                      63
# 157191                 2047                      63
# 157192                 2047                      63
# 157193                 2047                      63
#
#         barracks_status_radiant_x  first_blood_time_x  game_mode_x  \
# 157194                         63                   0           22
# 157190                         63                   0           22
# 157191                         63                   0           22
# 157192                         63                   0           22
# 157193                         63                   0           22
#
#         radiant_win_x         ...           unit_order_glyph  \
# 157194              0         ...                        NaN
# 157190              0         ...                        NaN
# 157191              0         ...                        NaN
# 157192              0         ...                        NaN
# 157193              0         ...                        NaN
#
#         unit_order_eject_item_from_stash  unit_order_cast_rune  \
# 157194                               NaN                   NaN
# 157190                               NaN                   NaN
# 157191                               NaN                   NaN
# 157192                               NaN                   NaN
# 157193                               NaN                   NaN
#
#         unit_order_ping_ability  unit_order_move_to_direction  \
# 157194                      NaN                           NaN
# 157190                      NaN                           NaN
# 157191                      NaN                           NaN
# 157192                      NaN                           NaN
# 157193                      NaN                           NaN
#
#         unit_order_patrol  unit_order_vector_target_position  \
# 157194                NaN                                NaN
# 157190                NaN                                NaN
# 157191                NaN                                NaN
# 157192                NaN                                NaN
# 157193                NaN                                NaN
#
#         unit_order_radar  unit_order_set_item_combine_lock  \
# 157194               NaN                               NaN
# 157190               NaN                               NaN
# 157191               NaN                               NaN
# 157192               NaN                               NaN
# 157193               NaN                               NaN
#
#         unit_order_continue
# 157194                  NaN
# 157190                  NaN
# 157191                  NaN
# 157192                  NaN
# 157193                  NaN
#
# [5 rows x 97 columns]

# %%
df_mat_sort.shape
# Out:
# (250000, 97)

# %%
# sortierte df nach Dauer nur mit Spalte Dauer beschreiben, um Klassengrößen festzulegen 
df_mat_sort["duration_x"].describe()
# Out:
# count    250000.000000
# mean       2476.453500
# std         634.626184
# min          59.000000
# 25%        2029.000000
# 50%        2415.000000
# 75%        2872.000000
# max       16037.000000
# Name: duration_x, dtype: float64

# %%
# Spalte duration_x in einem Boxplot visualisieren
sns.boxplot(df_mat_sort["duration_x"]);

# %%
# Spalte mit Klassen für die Dauer erstellen
df_mat_sort_bins = df_mat_sort['duration_x'].quantile(q=[x/10 for x in range (11)])
df_mat_sort_bins = [x*300 for x in range(57)]
df_mat_sort_bins_label = [x*5 for x in range(1,57)]
df_mat_sort["bins"] = pd.cut(df_mat_sort['duration_x'], bins=df_mat_sort_bins, labels=df_mat_sort_bins_label)

# %%
df_mat_sort_bins[:5]
df_mat_sort.head()
# Out:
#         match_id  start_time_x  duration_x  tower_status_radiant_x  \
# 157194     31438    1447625450          59                    2047
# 157190     31438    1447625450          59                    2047
# 157191     31438    1447625450          59                    2047
# 157192     31438    1447625450          59                    2047
# 157193     31438    1447625450          59                    2047
#
#         tower_status_dire_x  barracks_status_dire_x  \
# 157194                 2047                      63
# 157190                 2047                      63
# 157191                 2047                      63
# 157192                 2047                      63
# 157193                 2047                      63
#
#         barracks_status_radiant_x  first_blood_time_x  game_mode_x  \
# 157194                         63                   0           22
# 157190                         63                   0           22
# 157191                         63                   0           22
# 157192                         63                   0           22
# 157193                         63                   0           22
#
#         radiant_win_x  ...   unit_order_eject_item_from_stash  \
# 157194              0  ...                                NaN
# 157190              0  ...                                NaN
# 157191              0  ...                                NaN
# 157192              0  ...                                NaN
# 157193              0  ...                                NaN
#
#         unit_order_cast_rune  unit_order_ping_ability  \
# 157194                   NaN                      NaN
# 157190                   NaN                      NaN
# 157191                   NaN                      NaN
# 157192                   NaN                      NaN
# 157193                   NaN                      NaN
#
#         unit_order_move_to_direction  unit_order_patrol  \
# 157194                           NaN                NaN
# 157190                           NaN                NaN
# 157191                           NaN                NaN
# 157192                           NaN                NaN
# 157193                           NaN                NaN
#
#         unit_order_vector_target_position  unit_order_radar  \
# 157194                                NaN               NaN
# 157190                                NaN               NaN
# 157191                                NaN               NaN
# 157192                                NaN               NaN
# 157193                                NaN               NaN
#
#         unit_order_set_item_combine_lock  unit_order_continue  bins
# 157194                               NaN                  NaN     5
# 157190                               NaN                  NaN     5
# 157191                               NaN                  NaN     5
# 157192                               NaN                  NaN     5
# 157193                               NaN                  NaN     5
#
# [5 rows x 98 columns]

# %%
df_mat_sort.shape
# Out:
# (250000, 98)

# %%
table = df_mat_sort['bins'].value_counts()
table
# Out:
# 40     49100
# 45     44740
# 35     40735
# 50     34465
# 30     23525
# 55     22685
# 60     12720
# 25      7090
# 65      7015
# 70      3345
# 20      1555
# 75      1410
# 80       635
# 15       405
# 10       190
# 85       180
# 90        75
# 5         70
# 95        30
# 115       10
# 270        5
# 100        5
# 105        5
# 110        5
# 135        0
# 120        0
# 125        0
# 130        0
# 280        0
# 275        0
# 210        0
# 265        0
# 260        0
# 255        0
# 250        0
# 245        0
# 240        0
# 235        0
# 230        0
# 225        0
# 220        0
# 215        0
# 205        0
# 145        0
# 200        0
# 195        0
# 190        0
# 185        0
# 180        0
# 175        0
# 170        0
# 165        0
# 160        0
# 155        0
# 150        0
# 140        0
# Name: bins, dtype: int64

# %%
# Häufigkeitsverteilung der Klassen
plt.figure(figsize=(16.69, 4.27))
sns.countplot(x='bins', data=df_mat_sort);

# %%
df_mat_sort.shape
# Out:
# (250000, 98)

# %%
# datentyp category von Spalte "klassen" in int umwandeln
df_mat_sort["bins"] = df_mat_sort.bins.astype(int)

# %%
# DataFram mit 3 Klassen für die Dauer erstellen
df_mat_sort["klassen"] = pd.DataFrame({'klassen': pd.cut(df_mat_sort['bins'], bins=[0,35,50,280], labels=["kurz", "mittel", "lang"])})

# %%
plt.figure(figsize=(16.69, 4.27))
sns.countplot(x='klassen', data=df_mat_sort);

# %%
df_mat_sort.head()
# Out:
#         match_id  start_time_x  duration_x  tower_status_radiant_x  \
# 157194     31438    1447625450          59                    2047
# 157190     31438    1447625450          59                    2047
# 157191     31438    1447625450          59                    2047
# 157192     31438    1447625450          59                    2047
# 157193     31438    1447625450          59                    2047
#
#         tower_status_dire_x  barracks_status_dire_x  \
# 157194                 2047                      63
# 157190                 2047                      63
# 157191                 2047                      63
# 157192                 2047                      63
# 157193                 2047                      63
#
#         barracks_status_radiant_x  first_blood_time_x  game_mode_x  \
# 157194                         63                   0           22
# 157190                         63                   0           22
# 157191                         63                   0           22
# 157192                         63                   0           22
# 157193                         63                   0           22
#
#         radiant_win_x   ...     unit_order_cast_rune  unit_order_ping_ability  \
# 157194              0   ...                      NaN                      NaN
# 157190              0   ...                      NaN                      NaN
# 157191              0   ...                      NaN                      NaN
# 157192              0   ...                      NaN                      NaN
# 157193              0   ...                      NaN                      NaN
#
#         unit_order_move_to_direction  unit_order_patrol  \
# 157194                           NaN                NaN
# 157190                           NaN                NaN
# 157191                           NaN                NaN
# 157192                           NaN                NaN
# 157193                           NaN                NaN
#
#         unit_order_vector_target_position  unit_order_radar  \
# 157194                                NaN               NaN
# 157190                                NaN               NaN
# 157191                                NaN               NaN
# 157192                                NaN               NaN
# 157193                                NaN               NaN
#
#         unit_order_set_item_combine_lock  unit_order_continue  bins  klassen
# 157194                               NaN                  NaN     5     kurz
# 157190                               NaN                  NaN     5     kurz
# 157191                               NaN                  NaN     5     kurz
# 157192                               NaN                  NaN     5     kurz
# 157193                               NaN                  NaN     5     kurz
#
# [5 rows x 99 columns]

# %%
df3 = df_mat_sort[df_mat_sort.klassen == "kurz"]

# %%
df3.head()
# Out:
#         match_id  start_time_x  duration_x  tower_status_radiant_x  \
# 157194     31438    1447625450          59                    2047
# 157190     31438    1447625450          59                    2047
# 157191     31438    1447625450          59                    2047
# 157192     31438    1447625450          59                    2047
# 157193     31438    1447625450          59                    2047
#
#         tower_status_dire_x  barracks_status_dire_x  \
# 157194                 2047                      63
# 157190                 2047                      63
# 157191                 2047                      63
# 157192                 2047                      63
# 157193                 2047                      63
#
#         barracks_status_radiant_x  first_blood_time_x  game_mode_x  \
# 157194                         63                   0           22
# 157190                         63                   0           22
# 157191                         63                   0           22
# 157192                         63                   0           22
# 157193                         63                   0           22
#
#         radiant_win_x   ...     unit_order_cast_rune  unit_order_ping_ability  \
# 157194              0   ...                      NaN                      NaN
# 157190              0   ...                      NaN                      NaN
# 157191              0   ...                      NaN                      NaN
# 157192              0   ...                      NaN                      NaN
# 157193              0   ...                      NaN                      NaN
#
#         unit_order_move_to_direction  unit_order_patrol  \
# 157194                           NaN                NaN
# 157190                           NaN                NaN
# 157191                           NaN                NaN
# 157192                           NaN                NaN
# 157193                           NaN                NaN
#
#         unit_order_vector_target_position  unit_order_radar  \
# 157194                                NaN               NaN
# 157190                                NaN               NaN
# 157191                                NaN               NaN
# 157192                                NaN               NaN
# 157193                                NaN               NaN
#
#         unit_order_set_item_combine_lock  unit_order_continue  bins  klassen
# 157194                               NaN                  NaN     5     kurz
# 157190                               NaN                  NaN     5     kurz
# 157191                               NaN                  NaN     5     kurz
# 157192                               NaN                  NaN     5     kurz
# 157193                               NaN                  NaN     5     kurz
#
# [5 rows x 99 columns]

# %%
df_kurz = pd.DataFrame(df_mat_sort[df_mat_sort.klassen == "kurz"].groupby('hero_id').mean()['radiant_win_x'], index=np.arange(113))
df_kurz.columns =["winrate_kurz"]
df_kurz["hero_id"] = np.arange(1,114)

# %%
df_mittel = pd.DataFrame(df_mat_sort[df_mat_sort.klassen == "mittel"].groupby('hero_id').mean()['radiant_win_x'], index=np.arange(113))
df_mittel.columns =["winrate_mittel"]
df_mittel["hero_id"] = np.arange(1,114)

# %%
df_lang = pd.DataFrame(df_mat_sort[df_mat_sort.klassen == "lang"].groupby('hero_id').mean()['radiant_win_x'], index=np.arange(113))
df_lang.columns =["winrate_lang"]
df_lang["hero_id"] = np.arange(1,114)

# %%
df_hero_names = df_hero_names.merge(df_kurz, left_on='hero_id', right_on='hero_id', how='outer')
df_hero_names = df_hero_names.merge(df_mittel, left_on='hero_id', right_on='hero_id', how='outer')
df_hero_names = df_hero_names.merge(df_lang, left_on='hero_id', right_on='hero_id', how='outer')

# %%
df_hero_names.drop([109, 110, 111, 112], inplace=True)

# %%
df_most_played_heros = df_hero_names.sort_values(by="total_plays").tail(10)

# %%
df_most_played_heros.sort_values(by="winrate")
# Out:
#     total_plays                              name  hero_id     localized_name  \
# 97       5207.0             npc_dota_hero_abaddon      102            Abaddon
# 25       5445.0        npc_dota_hero_witch_doctor       30       Witch Doctor
# 19      10324.0                npc_dota_hero_zuus       22               Zeus
# 70       4963.0            npc_dota_hero_silencer       75           Silencer
# 12       4815.0               npc_dota_hero_razor       15              Razor
# 5        5838.0          npc_dota_hero_juggernaut        8         Juggernaut
# 6        5137.0              npc_dota_hero_mirana        9             Mirana
# 9        9008.0      npc_dota_hero_phantom_lancer       12     Phantom Lancer
# 36       5190.0       npc_dota_hero_faceless_void       41      Faceless Void
# 71       5824.0  npc_dota_hero_obsidian_destroyer       76  Outworld Devourer
#
#      winrate  winrate_kurz  winrate_mittel  winrate_lang
# 97  0.453104      0.476303        0.446154      0.439103
# 25  0.498328      0.576812        0.455285      0.495763
# 19  0.500581      0.560071        0.483121      0.466158
# 70  0.507040      0.577926        0.472564      0.495719
# 12  0.514019      0.569291        0.497849      0.484818
# 5   0.521411      0.571521        0.512989      0.479518
# 6   0.524041      0.596644        0.499420      0.449029
# 9   0.531194      0.618836        0.496798      0.466966
# 36  0.540810      0.643902        0.521333      0.461095
# 71  0.551839      0.605882        0.533654      0.522759

# %%
df_most_played_heros.winrate_kurz.plot.bar()

# %%
df_most_played_heros.winrate_mittel.plot.bar()

# %%
df_most_played_heros.winrate_lang.plot.bar()

# %%
fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax
ax3 = ax
ax4 = ax

width = 0.1

df_most_played_heros.winrate.plot(kind='bar', color='blue', ax=ax, width=width, position=3)
df_most_played_heros.winrate_kurz.plot(kind='bar', color='green', ax=ax2, width=width, position=2)
df_most_played_heros.winrate_mittel.plot(kind='bar', color='black', ax=ax3, width=width, position=1)
df_most_played_heros.winrate_lang.plot(kind='bar', color='red', ax=ax4, width=width, position=0)

ax.set_ylabel('Geweinnrate')
ax.set_xlabel('Helden')
plt.show()

# %%
sns.heatmap(df_hero_names.corr())

# %%
model = sm.ols(data=df_mat_sort, formula='hero_id~duration_x').fit()
print(model.summary())
# Bestimmtheitsmaß bzw. Determinationskoeffizient (R-squared) liegt bei 0,000 und enstspricht
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                hero_id   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     19.33
# Date:                Sat, 24 Jun 2017   Prob (F-statistic):           1.10e-05
# Time:                        15:42:36   Log-Likelihood:            -1.2277e+06
# No. Observations:              250000   AIC:                         2.455e+06
# Df Residuals:                  249998   BIC:                         2.455e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     51.6022      0.265    194.995      0.000        51.084    52.121
# duration_x    -0.0005      0.000     -4.397      0.000        -0.001    -0.000
# ==============================================================================
# Omnibus:                   244240.674   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17210.231
# Skew:                           0.218   Prob(JB):                         0.00
# Kurtosis:                       1.791   Cond. No.                     1.03e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# hier wird der Zusammenhang zwischen Champions und Dauer des Spiels dargestellt
sns.regplot(data=df_mat_sort, x='hero_id', y='bins');

# %%
sns.heatmap(df_gb_heroID.corr());
