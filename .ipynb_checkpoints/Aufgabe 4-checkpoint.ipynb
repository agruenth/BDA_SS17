# %% [markdown]
# ## Aufgabe 4
# ## Import von Bibliotheken

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt
sns.set(context="paper", font="monospace")

# %% [markdown]
# ## Einlesen der Dateien

# %%
df_players = pd.read_csv('data/players.csv', memory_map=True)
df_match_50000 = pd.read_csv('data/match.csv' ,memory_map=True, nrows=50000)
df_match_500 = pd.read_csv('data/match.csv' ,memory_map=True, nrows=500)
df_hero_names = pd.read_csv('data/hero_names.csv', memory_map=True  )
# df_chat = pd.read_csv('data/dota-2-matches/chat.csv', memory_map=True)

# %% [markdown]
# ## Auswahl der benötigten Daten

# %%
full_list = list(df_match_50000.columns)
wanted = ['match_id','duration','radiant_win']
df_match_50000.drop(full_list-wante)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-07b43d848d5a> in <module>()
#       1 full_list = list(df_match_50000.columns)
#       2 wanted = ['match_id','duration','radiant_win']
# ----> 3 df_match_50000.drop((full_list-wanted))
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %% [markdown]
# ## Überprüfen auf fehlenden Werte

# %%
print ("Na Werte \t" +  str(df_match_50000.isnull().sum()))
# Out:
# Na Werte 	match_id                   0
# start_time                 0
# duration                   0
# tower_status_radiant       0
# tower_status_dire          0
# barracks_status_dire       0
# barracks_status_radiant    0
# first_blood_time           0
# game_mode                  0
# radiant_win                0
# negative_votes             0
# positive_votes             0
# cluster                    0
# dtype: int64

# %%
print ("Na Werte \t" +  str(df_players.isnull().sum()))
print("\n\nDie NA Werte sind nicht zu bereinigen, mit ihnen muss umgegangen werden.")
# Out:
# Na Werte 	match_id                                  0
# account_id                                0
# hero_id                                   0
# player_slot                               0
# gold                                      0
# gold_spent                                0
# gold_per_min                              0
# xp_per_min                                0
# kills                                     0
# deaths                                    0
# assists                                   0
# denies                                    0
# last_hits                                 0
# stuns                                     0
# hero_damage                               0
# hero_healing                              0
# tower_damage                              0
# item_0                                    0
# item_1                                    0
# item_2                                    0
# item_3                                    0
# item_4                                    0
# item_5                                    0
# level                                     0
# leaver_status                             0
# xp_hero                                1883
# xp_creep                                 68
# xp_roshan                            320438
# xp_other                              21036
# gold_other                            94897
#                                       ...
# unit_order_attack_target                105
# unit_order_cast_position               2269
# unit_order_cast_target                16674
# unit_order_cast_target_tree           35712
# unit_order_cast_no_target               892
# unit_order_cast_toggle               401211
# unit_order_hold_position             137277
# unit_order_train_ability                 73
# unit_order_drop_item                 288667
# unit_order_give_item                 394631
# unit_order_pickup_item               244658
# unit_order_pickup_rune                74517
# unit_order_purchase_item                 57
# unit_order_sell_item                 111866
# unit_order_disassemble_item          485446
# unit_order_move_item                   4264
# unit_order_cast_toggle_auto          463670
# unit_order_stop                      412425
# unit_order_taunt                     500000
# unit_order_buyback                   352233
# unit_order_glyph                     273230
# unit_order_eject_item_from_stash     468736
# unit_order_cast_rune                 499991
# unit_order_ping_ability              160852
# unit_order_move_to_direction         496449
# unit_order_patrol                    500000
# unit_order_vector_target_position    500000
# unit_order_radar                     500000
# unit_order_set_item_combine_lock     500000
# unit_order_continue                  500000
# dtype: int64
#
#
# Die NA Werte sind nicht zu bereinigen, mit ihnen muss umgegangen werden.

# %%
print ("Na Werte \t" +  str(df_hero_names.isnull().sum()))
# Out:
# Na Werte 	name              0
# hero_id           0
# localized_name    0
# dtype: int64

# %% [markdown]
# ## Überprüfung auf Ausreiser

# %%
"""
# Visuelle Überprüfung auf Ausreißer mit Hilfe von Boxplots

# get numeric columns to check
cols = df_players.select_dtypes(include=[np.number]).columns
fig, axes = plt.subplots(nrows=len(cols), ncols=1)
# draw boxplot for each col ... need index to address axes
for i in range(len(cols)):
    sns.boxplot(x=cols[i], orient='h', data=df_players, ax=axes[i])
    fig.tight_layout()
    plt.show()

# improve spacing and show
fig.tight_layout()
plt.show()
"""
# Out:
# "\n# Visuelle Überprüfung auf Ausreißer mit Hilfe von Boxplots\n\n# get numeric columns to check\ncols = df_players.select_dtypes(include=[np.number]).columns\nfig, axes = plt.subplots(nrows=len(cols), ncols=1)\n# draw boxplot for each col ... need index to address axes\nfor i in range(len(cols)):\n    sns.boxplot(x=cols[i], orient='h', data=df_players, ax=axes[i])\n    fig.tight_layout()\n    plt.show()\n\n# improve spacing and show\nfig.tight_layout()\nplt.show()\n"

# %% [markdown]
# ## Gibt es Helden die erfolgreicher sind als andere?

# %%
df_match_50000["radiant_win"] = df_match_50000.radiant_win.astype(int)
mat = df_match_50000.merge(df_match_50000,on='match_id').merge(df_players[df_players["player_slot"]<6],on='match_id')

# %%
# mat.groupby('hero_id').mean()['radiant_win_x']
df_gb_heroID = pd.DataFrame(mat.groupby('hero_id').mean()['radiant_win_x'], index=np.arange(113))
df_gb_heroID.columns =["winrate"]
df_gb_heroID["hero_id"] = np.arange(1,114)
df_gb_heroID
# Out:
#       winrate  hero_id
# 0    0.136364        1
# 1    0.484149        2
# 2    0.454823        3
# 3    0.487500        4
# 4    0.469646        5
# 5    0.562169        6
# 6    0.518660        7
# 7    0.521411        8
# 8    0.524041        9
# 9    0.539709       10
# 10   0.446667       11
# 11   0.531194       12
# 12   0.471668       13
# 13   0.435838       14
# 14   0.514019       15
# 15   0.506250       16
# 16   0.489172       17
# 17   0.428571       18
# 18   0.535632       19
# 19   0.503440       20
# 20   0.542603       21
# 21   0.500581       22
# 22   0.581858       23
# 23   0.487023       24
# 24        NaN       25
# 25   0.451009       26
# 26   0.492295       27
# 27   0.561659       28
# 28   0.576860       29
# 29   0.498328       30
# ..        ...      ...
# 83   0.532131       84
# 84   0.541724       85
# 85   0.592802       86
# 86   0.472772       87
# 87   0.539260       88
# 88   0.502203       89
# 89   0.463265       90
# 90   0.470968       91
# 91   0.474390       92
# 92   0.520343       93
# 93   0.497965       94
# 94   0.540928       95
# 95   0.500000       96
# 96   0.537797       97
# 97   0.470041       98
# 98   0.472889       99
# 99   0.485469      100
# 100  0.535433      101
# 101  0.453104      102
# 102  0.599644      103
# 103  0.507282      104
# 104  0.506303      105
# 105  0.467337      106
# 106  0.505670      107
# 107  0.528234      108
# 108       NaN      109
# 109  0.536388      110
# 110  0.536697      111
# 111  0.498008      112
# 112  0.530549      113
#
# [113 rows x 2 columns]

# %%
df_hero_names.head(113)
df_hero_names = df_hero_names.merge(df_gb_heroID, left_on='hero_id', right_on='hero_id', how='outer')
df_hero_names.head(113)
# Out:
#                                   name  hero_id       localized_name   winrate
# 0               npc_dota_hero_antimage      1.0            Anti-Mage  0.136364
# 1                    npc_dota_hero_axe      2.0                  Axe  0.484149
# 2                   npc_dota_hero_bane      3.0                 Bane  0.454823
# 3            npc_dota_hero_bloodseeker      4.0          Bloodseeker  0.487500
# 4         npc_dota_hero_crystal_maiden      5.0       Crystal Maiden  0.469646
# 5            npc_dota_hero_drow_ranger      6.0          Drow Ranger  0.562169
# 6            npc_dota_hero_earthshaker      7.0          Earthshaker  0.518660
# 7             npc_dota_hero_juggernaut      8.0           Juggernaut  0.521411
# 8                 npc_dota_hero_mirana      9.0               Mirana  0.524041
# 9              npc_dota_hero_morphling     10.0            Morphling  0.539709
# 10             npc_dota_hero_nevermore     11.0         Shadow Fiend  0.446667
# 11        npc_dota_hero_phantom_lancer     12.0       Phantom Lancer  0.531194
# 12                  npc_dota_hero_puck     13.0                 Puck  0.471668
# 13                 npc_dota_hero_pudge     14.0                Pudge  0.435838
# 14                 npc_dota_hero_razor     15.0                Razor  0.514019
# 15             npc_dota_hero_sand_king     16.0            Sand King  0.506250
# 16          npc_dota_hero_storm_spirit     17.0         Storm Spirit  0.489172
# 17                  npc_dota_hero_sven     18.0                 Sven  0.428571
# 18                  npc_dota_hero_tiny     19.0                 Tiny  0.535632
# 19        npc_dota_hero_vengefulspirit     20.0      Vengeful Spirit  0.503440
# 20            npc_dota_hero_windrunner     21.0           Windranger  0.542603
# 21                  npc_dota_hero_zuus     22.0                 Zeus  0.500581
# 22                npc_dota_hero_kunkka     23.0               Kunkka  0.581858
# 23                  npc_dota_hero_lina     25.0                 Lina       NaN
# 24                  npc_dota_hero_lion     26.0                 Lion  0.451009
# 25         npc_dota_hero_shadow_shaman     27.0        Shadow Shaman  0.492295
# 26               npc_dota_hero_slardar     28.0              Slardar  0.561659
# 27            npc_dota_hero_tidehunter     29.0           Tidehunter  0.576860
# 28          npc_dota_hero_witch_doctor     30.0         Witch Doctor  0.498328
# 29                  npc_dota_hero_lich     31.0                 Lich  0.532731
# ..                                 ...      ...                  ...       ...
# 83               npc_dota_hero_undying     85.0              Undying  0.541724
# 84                npc_dota_hero_rubick     86.0               Rubick  0.592802
# 85             npc_dota_hero_disruptor     87.0            Disruptor  0.472772
# 86          npc_dota_hero_nyx_assassin     88.0         Nyx Assassin  0.539260
# 87            npc_dota_hero_naga_siren     89.0           Naga Siren  0.502203
# 88   npc_dota_hero_keeper_of_the_light     90.0  Keeper of the Light  0.463265
# 89                  npc_dota_hero_wisp     91.0                   Io  0.470968
# 90                npc_dota_hero_visage     92.0               Visage  0.474390
# 91                 npc_dota_hero_slark     93.0                Slark  0.520343
# 92                npc_dota_hero_medusa     94.0               Medusa  0.497965
# 93         npc_dota_hero_troll_warlord     95.0        Troll Warlord  0.540928
# 94               npc_dota_hero_centaur     96.0    Centaur Warrunner  0.500000
# 95             npc_dota_hero_magnataur     97.0               Magnus  0.537797
# 96              npc_dota_hero_shredder     98.0            Timbersaw  0.470041
# 97           npc_dota_hero_bristleback     99.0          Bristleback  0.472889
# 98                  npc_dota_hero_tusk    100.0                 Tusk  0.485469
# 99         npc_dota_hero_skywrath_mage    101.0        Skywrath Mage  0.535433
# 100              npc_dota_hero_abaddon    102.0              Abaddon  0.453104
# 101          npc_dota_hero_elder_titan    103.0          Elder Titan  0.599644
# 102     npc_dota_hero_legion_commander    104.0     Legion Commander  0.507282
# 103              npc_dota_hero_techies    105.0              Techies  0.506303
# 104         npc_dota_hero_ember_spirit    106.0         Ember Spirit  0.467337
# 105         npc_dota_hero_earth_spirit    107.0         Earth Spirit  0.505670
# 106    npc_dota_hero_abyssal_underlord    108.0            Underlord  0.528234
# 107          npc_dota_hero_terrorblade    109.0          Terrorblade       NaN
# 108              npc_dota_hero_phoenix    110.0              Phoenix  0.536388
# 109               npc_dota_hero_oracle    111.0               Oracle  0.536697
# 110        npc_dota_hero_winter_wyvern    112.0        Winter Wyvern  0.498008
# 111           npc_dota_hero_arc_warden    113.0           Arc Warden  0.530549
# 112                                NaN     24.0                  NaN  0.487023
#
# [113 rows x 4 columns]

# %%
sns.violinplot(data=df_hero_names.winrate, orient="h");

# sns.barplot(orient="h",data=df_hero_names.sort("winrate"),x="localized_name", y="winrate")

# %% [markdown]
# ## Prüfen ob gewisse Helden öfter gespielt werden als andere

# %%
df_hero_names = mat.hero_id.value_counts().to_frame(name="total_plays").merge(df_hero_names,left_index=True, right_index=True)

# %%
sns.regplot(data=df_hero_names, y="winrate", x="total_plays")

# %%
# Entfernen des Ausreisers
df_hero_names.drop(df_hero_names.winrate<0.14, inplace=True)

# %%
 sns.regplot(data=df_hero_names, y="winrate", x="total_plays")

# %%
df_hero_names.corr()
# Out:
#              total_plays   hero_id   winrate
# total_plays     1.000000 -0.246683  0.157869
# hero_id        -0.246683  1.000000 -0.013915
# winrate         0.157869 -0.013915  1.000000

# %% [markdown]
# ## Ist die Winrate der Champions abhängig von der Spieldauer?

# %%
pd.cut(mat['duration'], bins, labels=group_names)

# %%
mat.drop(mat['duration_x']>7000)
mat.columns
# mat.duration_y.plot.box()
# mat.drop(mat.duration_y >7000, inplace=True)
# sns.boxplot(data=mat.duration_y)
# mat[mat.duration_y >7000]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-6b85ccea0eff> in <module>()
# ----> 1 mat.drop(mat['duration_x']>7000)
#       2 mat.columns
#       3 # mat.duration_y.plot.box()
#       4 # mat.drop(mat.duration_y >7000, inplace=True)
#       5 # sns.boxplot(data=mat.duration_y)
#
# C:\Users\Adria\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# C:\Users\Adria\Anaconda3\lib\site-packages\pandas\indexes\base.py in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
#    3052             indexer = indexer[~mask]
#    3053         return self.delete(indexer)
#
# ValueError: labels [False False False ..., False False False] not contained in axis
